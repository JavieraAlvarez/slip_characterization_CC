# %% [markdown]
# # Uncertainties associated - 1730 case
# Javiera Álvarez, 2024.
#
# The number of qualitative and quantitative data recorded for each seismic event determines the number of models that pass all restriction filters. This leads to the question of which of these models most accurately represents the specific event. To address this, we take into account the uncertainties inherent in all models for the 1730, 1906 and 1985 earthquakes that have gone through the restriction process.

# %% [markdown]
# ### Mean and STD on each point of data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Constrained .CSV files
# Note: A for-loop could be implemented for processing all files in directory
model1 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_845_aumentado_filtered.csv', header=None)
model2 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_876_aumentado_filtered.csv', header=None)
model3 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_959_aumentado_filtered.csv', header=None)
model4 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_986_aumentado_filtered.csv', header=None)
model5 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_1863_aumentado_filtered.csv', header=None)
model6 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_1871_aumentado_filtered.csv', header=None)
model7 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_1995_aumentado_filtered.csv', header=None)
model8 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_3863_aumentado_filtered.csv', header=None)
model9 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4815_aumentado_filtered.csv', header=None)
model10 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4831_aumentado_filtered.csv', header=None)
model11 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4834_aumentado_filtered.csv', header=None)
model12 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4945_aumentado_filtered.csv', header=None)
model13 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_5871_aumentado_filtered.csv', header=None)
model14 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_5888_aumentado_filtered.csv', header=None)
model15 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_5898_aumentado_filtered.csv', header=None)
model16 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_6864_aumentado_filtered.csv', header=None)
model17 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_6882_aumentado_filtered.csv', header=None)
model18 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_7940_aumentado_filtered.csv', header=None)

# slip models
models = np.stack([model1.iloc[:, 2].values, 
                   model2.iloc[:, 2].values, 
                   model3.iloc[:, 2].values, 
                   model4.iloc[:, 2].values, 
                   model5.iloc[:, 2].values, 
                   model6.iloc[:, 2].values,
                   model7.iloc[:, 2].values,
                   model8.iloc[:, 2].values,
                   model9.iloc[:, 2].values,
                   model10.iloc[:, 2].values,
                   model11.iloc[:, 2].values,
                   model12.iloc[:, 2].values,
                   model13.iloc[:, 2].values,
                   model14.iloc[:, 2].values,
                   model15.iloc[:, 2].values,
                   model16.iloc[:, 2].values,
                   model17.iloc[:, 2].values,
                   model18.iloc[:, 2].values,
                   ])

# Mean and STD on each point of data
mean_slip = np.mean(models, axis=0)
std_slip = np.std(models, axis=0)

# lat and lon extract
lat = model1.iloc[:, 1].values  # Lat
lon = model1.iloc[:, 0].values  # Lon

# We create a DataFrame with the data
slip_df = pd.DataFrame({
    'Lon': lon,
    'Lat': lat,
    'Mean_Slip': mean_slip,
    'Std_Slip': std_slip
})

print(mean_slip)

#FIGURES

# mean
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Lon', y='Lat', size='Mean_Slip', hue='Mean_Slip', sizes=(20, 200), 
                palette='hot_r', data=slip_df, legend=True) 
plt.title('Mean Slip Displacement Across Models')
plt.savefig('MEAN_1730.png', dpi=300, bbox_inches='tight')
plt.show()

# std
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Lon', y='Lat', size='Std_Slip', hue='Std_Slip', sizes=(20, 200), palette='coolwarm', data=slip_df)
plt.title('Uncertainty in Slip Displacement (Std)')
plt.savefig('STD_1730.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# [10.52938741  9.12617824  7.17494524  5.03347948  3.03883207  1.41494343
#   0.35859824  0.         10.84032361 11.25951171 10.91977522  9.72970942
#   7.88026889  5.73890161  3.65763012  1.87935306  0.61903841  0.03505811
#  10.81620615 11.32773652 11.23825313 10.28126472  8.58818962  6.48846805
#   4.33295587  2.41271231  0.95617583  0.14497641 10.88274816 11.36872983
#  11.50348595 10.7908053   9.28150776  7.2485628   5.0514108   2.9985249
#   1.35988979  0.33028338 10.92933151 11.43739624 11.73009098 11.27204571
#   9.96033728  8.02043816  5.8116235   3.63949186  1.83075865  0.59193715
#  11.00183261 11.52274933 11.89361341 11.58159551 10.36857861  8.46607017
#   6.24134512  4.00480466  2.10543437  0.7619653  11.03695997 11.61019034
#  12.03774251 11.84051659 10.71557375  8.86464709  6.6217085   4.33691189
#   2.3610301   0.92226498 11.03913948 11.65341263 12.1417533  12.06514296
#  11.04483023  9.24609073  7.01046049  4.69666265  2.64186275  1.10055758
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.interpolate import griddata

# Load deformation data from CSV file 
def_data = pd.read_csv('def_magnitud_1906.csv', delimiter=r"\s+", header=None)

# Extract coordinates and magnitude values
def_lon = def_data.iloc[:, 0].values
def_lat = def_data.iloc[:, 1].values
def_magnitude = def_data.iloc[:, 2].values

# Create array of deformation points coordinates
def_points = np.column_stack((def_lon, def_lat))

# Model input preparation
# Required arrays: 
# - lon: longitude points for slip models
# - lat: latitude points for slip models  
# - models: array of slip values with shape (n_models, n_points)

# Interpolate slip values for each model at deformation points
slip_interpolated = []

for i in range(models.shape[0]):
    slip_interp = griddata((lon, lat), models[i], def_points, method='linear')
    slip_interpolated.append(slip_interp)

# array of interpolate slip
slip_interpolated = np.array(slip_interpolated)

# Calculate RMSE between interpolated slip and observed deformation
rmse_values = []
for i in range(slip_interpolated.shape[0]):
     # Filter out NaN values for valid comparison
    mask = ~np.isnan(slip_interpolated[i]) & ~np.isnan(def_magnitude)
    if mask.sum() > 0:
        rmse = np.sqrt(mean_squared_error(def_magnitude[mask], slip_interpolated[i][mask]))
    else:
        rmse = np.nan 
    rmse_values.append(rmse)

rmse_values = np.array(rmse_values)

# Identify best performing model
best_model_index = np.nanargmin(rmse_values)
best_rmse = rmse_values[best_model_index]

print(f'El mejor modelo es el modelo {best_model_index + 1} con un RMSE de {best_rmse:.4f}')

# Visualization setup
model_labels = [f'Model {i+1}' for i in range(len(rmse_values))]

# Plot RMSE comparison
plt.figure(figsize=(10, 6))
plt.scatter(model_labels, rmse_values, color='blue', s=100)
plt.scatter(model_labels[best_model_index], best_rmse, color='red', s=200, label=f'Mejor Modelo (RMSE = {best_rmse:.4f})')
plt.xlabel('Modelos')
plt.ylabel('RMSE')
plt.title('Comparación de RMSE de los Modelos')
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Maximum mean and media slip ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# CSV files

model1 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_845_aumentado_filtered.csv', header=None)
model2 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_876_aumentado_filtered.csv', header=None)
model3 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_959_aumentado_filtered.csv', header=None)
model4 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_986_aumentado_filtered.csv', header=None)
model5 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_1863_aumentado_filtered.csv', header=None)
model6 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_1871_aumentado_filtered.csv', header=None)
model7 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_1995_aumentado_filtered.csv', header=None)
model8 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_3863_aumentado_filtered.csv', header=None)
model9 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4815_aumentado_filtered.csv', header=None)
model10 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4831_aumentado_filtered.csv', header=None)
model11 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4834_aumentado_filtered.csv', header=None)
model12 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_4945_aumentado_filtered.csv', header=None)
model13 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_5871_aumentado_filtered.csv', header=None)
model14 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_5888_aumentado_filtered.csv', header=None)
model15 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_5898_aumentado_filtered.csv', header=None)
model16 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_6864_aumentado_filtered.csv', header=None)
model17 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_6882_aumentado_filtered.csv', header=None)
model18 = pd.read_csv('/Users/javieraalvarezvargas/Desktop/modelos/milsietetreinta/filtrados72/slip_7940_aumentado_filtered.csv', header=None)

# slip models
models = np.stack([model1.iloc[:, 2].values, 
                   model2.iloc[:, 2].values, 
                   model3.iloc[:, 2].values, 
                   model4.iloc[:, 2].values, 
                   model5.iloc[:, 2].values, 
                   model6.iloc[:, 2].values,
                   model7.iloc[:, 2].values,
                   model8.iloc[:, 2].values,
                   model9.iloc[:, 2].values,
                   model10.iloc[:, 2].values,
                   model11.iloc[:, 2].values,
                   model12.iloc[:, 2].values,
                   model13.iloc[:, 2].values,
                   model14.iloc[:, 2].values,
                   model15.iloc[:, 2].values,
                   model16.iloc[:, 2].values,
                   model17.iloc[:, 2].values,
                   model18.iloc[:,2].values])

# mean_slip (media) & median_slip (mediana)
mean_slip = np.mean(models, axis=0)
median_slip = np.median(models, axis=0)
lat = model1.iloc[:, 1].values
lon = model1.iloc[:, 0].values

# coordinates with the maximum slip
def get_max_position(slip_array):
    max_index = np.argmax(slip_array)
    max_lat = lat[max_index]
    max_lon = lon[max_index]
    return max_lon, max_lat, slip_array[max_index]

# positions
model_max_positions = []
for model in models:
    lon_max, lat_max, max_value = get_max_position(model)
    model_max_positions.append((lon_max, lat_max, max_value))

# positions with maximum Mean y Median slip
mean_max_lon, mean_max_lat, mean_max_value = get_max_position(mean_slip)
median_max_lon, median_max_lat, median_max_value = get_max_position(median_slip)

# output
print("Coordenadas de los máximos por modelo:")
for i, pos in enumerate(model_max_positions):
    print(f"Modelo {i+1}: Lon = {pos[0]}, Lat = {pos[1]}, Max Slip = {pos[2]}")

print(f"\nMáximo Mean Slip: Lon = {mean_max_lon}, Lat = {mean_max_lat}, Slip = {mean_max_value}")
print(f"Máximo Median Slip: Lon = {median_max_lon}, Lat = {median_max_lat}, Slip = {median_max_value}")
# Out:
# Coordenadas de los máximos por modelo:
# Modelo 1: Lon = -72.8126713230127, Lat = -32.66530612244898, Max Slip = 24.86452086656116
# Modelo 2: Lon = -72.29453456234377, Lat = -32.48469387755102, Max Slip = 22.58662413120929
# Modelo 3: Lon = -72.47518185728875, Lat = -33.929591836734694, Max Slip = 22.351705839017697
# Modelo 4: Lon = -72.10876356094687, Lat = -33.38775510204081, Max Slip = 18.74153671139341
# Modelo 5: Lon = -72.3991529888209, Lat = -33.748979591836736, Max Slip = 21.10917684862433
# Modelo 6: Lon = -72.81189317750291, Lat = -33.38775510204081, Max Slip = 25.43152706731085
# Modelo 7: Lon = -72.81426311824784, Lat = -33.207142857142856, Max Slip = 18.68253274461879
# Modelo 8: Lon = -72.35573563536968, Lat = -33.0265306122449, Max Slip = 24.356889166312456
# Modelo 9: Lon = -72.00348416210564, Lat = -33.929591836734694, Max Slip = 18.28105520822824
# Modelo 10: Lon = -72.71103070488032, Lat = -33.929591836734694, Max Slip = 21.107778638363445
# ...

# %% [markdown]
# ## Maximum Slip Locations Across Models ##

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Input slip distribution models from filtered CSV files
files = [
    'slip_845_aumentado_filtered.csv', 'slip_876_aumentado_filtered.csv', 'slip_959_aumentado_filtered.csv',
    'slip_986_aumentado_filtered.csv', 'slip_1863_aumentado_filtered.csv', 'slip_1871_aumentado_filtered.csv',
    'slip_1995_aumentado_filtered.csv', 'slip_3863_aumentado_filtered.csv', 'slip_4815_aumentado_filtered.csv',
    'slip_4831_aumentado_filtered.csv', 'slip_4834_aumentado_filtered.csv', 'slip_4945_aumentado_filtered.csv',
    'slip_5871_aumentado_filtered.csv', 'slip_5888_aumentado_filtered.csv', 'slip_5898_aumentado_filtered.csv',
    'slip_6864_aumentado_filtered.csv', 'slip_6882_aumentado_filtered.csv', 'slip_7940_aumentado_filtered.csv'
]

# List
max_slip_positions = []

# Extract maximum slip values and their coordinates from each model
for i, file in enumerate(files):
    df = pd.read_csv(file, header=None)  # Raw data import
    max_slip = df[2].max()  # Identify maximum slip value in column 2
    max_row = df[df[2] == max_slip].iloc[0]  # Extract coordinates of maximum slip
    max_slip_positions.append({
        "Model": f'Model_{i + 1}',
        "Max_Slip": max_slip,
        "Lat": max_row[1],  # Latitude coordinate
        "Lon": max_row[0]   # Longitude coordinate
    })

# Convert to DataFrame for analysis
max_slip_positions_df = pd.DataFrame(max_slip_positions)

##################################

#PLOT

# Plot maximum slip locations with spatial distribution ('x')
plt.figure(figsize=(10, 6))
scatter = plt.scatter(max_slip_positions_df['Lon'], max_slip_positions_df['Lat'], 
                      c=max_slip_positions_df['Max_Slip'], cmap='hot_r', s=100, edgecolor='black', marker='x')
# Add model labels with offset to prevent overlap
for i, txt in enumerate(max_slip_positions_df['Model']):
    offset = 0.01 if i % 2 == 0 else -0.01  # Alternate label positions
    plt.annotate(txt, (max_slip_positions_df['Lon'][i], max_slip_positions_df['Lat'][i] + offset), 
                 fontsize=8, ha='left', va='bottom')
# Configure plot aesthetics
plt.title('Maximum Slip Locations Across Models', fontsize=14)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Max Slip')
# Export high-resolution figure
plt.savefig('maximumslip_location_1730.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/xn/kx3kjgds4gvc08brqnwvfk3h0000gn/T/ipykernel_20078/1822682299.py:38: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   scatter = plt.scatter(max_slip_positions_df['Lon'], max_slip_positions_df['Lat'],

# %% [markdown]
# # Uncertainty Analysis of Slip Distribution Models
#
# ### model_slip:
# Represents the slip values of the current model in the iteration, extracted from column 2 of each model file (such as model1, model2, etc.).
#
# ### mean_slip:
# Represents the average slip values previously calculated across all models
#
# ### Analysis Workflow:
# ----------------
# 1. Extract slip values from target model
# 2. Generate spatial cluster analysis based on coordinates and maximum slip
# 3. Compare cluster values against mean slip distribution using MSE
#    to identify optimal model performance
#
# Note: This analysis identifies spatial patterns and variations in slip
# distribution across multiple model iterations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch  # Import Patch from matplotlib.patches
from sklearn.metrics import mean_squared_error

# Assuming you already have the DataFrames 'max_slip_positions_df' and 'slip_df'

# Step 1: Extract maximum slip positions (Lat and Lon)
X = max_slip_positions_df[['Lat', 'Lon']].values  # Extract coordinates

# Step 2: Apply K-Means to find 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42)
max_slip_positions_df['Cluster'] = kmeans.fit_predict(X)

# Step 3: Define custom color palette (green, blue, yellow)
cluster_colors = ['#66c2a5', '#fc8d62', '#8da0cb'] 
cluster_labels = ['Cluster 1', 'Cluster 2', 'Cluster 3']  # Cluster names

# Get cluster centroid coordinates
centroids = kmeans.cluster_centers_

# Display centroids (Lat, Lon)
print("Cluster centroids:")
for i, centroid in enumerate(centroids):
    print(f"Cluster {i}: Lat = {centroid[0]}, Lon = {centroid[1]}")

# Create figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8))  # Two subplots in one row

# Step 4: Complete Plot (left)
scatter = sns.scatterplot(x='Lon', y='Lat', size='Mean_Slip', hue='Mean_Slip', sizes=(20, 200), 
                          palette='hot_r', data=slip_df, legend=True, ax=ax1)

# Add labels with semi-transparent boxes for clusters
for i, row in max_slip_positions_df.iterrows():
    cluster_id = row['Cluster']
    color = cluster_colors[cluster_id]
    ax1.annotate(row['Model'], (row['Lon'], row['Lat']), fontsize=10, ha='center', va='center', 
                 bbox=dict(facecolor=color, edgecolor='black', boxstyle='round,pad=0.2', alpha=0.5))  # 50% transparency

# Adjust complete plot limits
ax1.set_title('Maximum Slip Locations and Mean, 1730 Event', fontsize=18)
ax1.set_xlabel('Longitude')
ax1.set_ylabel('Latitude')

# Step 5: Zoomed Plot (right)
sns.scatterplot(x='Lon', y='Lat', size='Mean_Slip', hue='Mean_Slip', sizes=(20, 200), 
                palette='hot_r', data=slip_df, legend=False, ax=ax2)  # Don't show legend again

for i, row in max_slip_positions_df.iterrows():
    cluster_id = row['Cluster']
    color = cluster_colors[cluster_id]
    ax2.annotate(row['Model'], (row['Lon'], row['Lat']), fontsize=10, ha='center', va='center', 
                 bbox=dict(facecolor=color, edgecolor='black', boxstyle='round,pad=0.2', alpha=0.5))  # 50% transparency

# Apply zoom in second plot (right)
ax2.set_xlim(-73, -71.5)  # Longitude limits
ax2.set_ylim(-35, -31)  # Latitude limits

# Zoomed plot title
ax2.set_title('Zoomed-In View of Maximum Slip Locations and Mean')
ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')

# Step 6: Add custom legend for clusters below Mean Slip legend

# Create patch set for each color and cluster
handles_clusters = [Patch(color=color, label=label) for color, label in zip(cluster_colors, cluster_labels)]

# Get current Mean Slip legend
handles_mean_slip, labels_mean_slip = scatter.get_legend_handles_labels()

# Add Mean Slip legend first
ax1.legend(handles=handles_mean_slip, labels=labels_mean_slip, loc='upper left', fontsize=10, title='Mean Slip')

# Add clusters legend below
fig.legend(handles=handles_clusters, loc='upper left', bbox_to_anchor=(0.05, 0.75), fontsize=10, title="Clusters", title_fontsize='13')

# Adjust margins and spacing between subplots
plt.tight_layout()
plt.savefig('cluster_1730.png', dpi=300, bbox_inches='tight')
# Display plot
plt.show()

# Step 7: Show model count per cluster
print(max_slip_positions_df.groupby('Cluster').size())

##############################################################
# ======== Calculate Mean Coordinates and Max Slip for Cluster 2 ======== #
##############################################################

# List of model DataFrames
models = [
    model1, model2, model3, model4, model5, model6, model7, model8, model9, model10,
    model11, model12, model13, model14, model15, model16, model17, model18
]  # Adjust to include all models

# Filter models belonging to Cluster 2
cluster_2_models = max_slip_positions_df[max_slip_positions_df['Cluster'] == 1]  # Cluster 2 has ID = 1

# Step 1: Calculate mean coordinate of maximum slip in Cluster 2
mean_lat = cluster_2_models['Lat'].mean()
mean_lon = cluster_2_models['Lon'].mean()
mean_coordinates = np.array([mean_lat, mean_lon])

# Calculate average maximum slip in cluster
mean_max_slip_cluster_2 = cluster_2_models['Max_Slip'].mean()

# Initialize list to store MSE results for each model in Cluster 2
results = []

# Step 2: Calculate MSE between maximum slip coordinate and maximum slip of each model vs. cluster average maximum slip
for i, row in cluster_2_models.iterrows():
    # Calculate MSE for maximum slip coordinate
    model_coordinates = np.array([row['Lat'], row['Lon']])
    mse_coordinates = mean_squared_error(mean_coordinates, model_coordinates)
    
    # Get model number to access its data
    model_number = int(row['Model'].split('_')[1]) - 1  # Adjust index (model1 is 0 in list)
    if model_number < len(models):
        # Get maximum slip of current model
        model_max_slip = models[model_number].iloc[:, 2].max()
        # Calculate MSE between model maximum slip and cluster average maximum slip
        mse_max_slip = mean_squared_error([mean_max_slip_cluster_2], [model_max_slip])
        # Add results to list
        results.append((row['Model'], mse_coordinates, mse_max_slip))
    else:
        print(f"Warning: Model {row['Model']} is not defined in the models list.")

# Create DataFrame with MSE results
mse_df = pd.DataFrame(results, columns=['Model', 'MSE_Coordinates', 'MSE_Max_Slip'])

# Sort results by MSE from lowest to highest to identify best model in both metrics
mse_df_sorted = mse_df.sort_values(by=['MSE_Coordinates', 'MSE_Max_Slip'])

# Display model closest to average in terms of coordinates and maximum slip
best_model = mse_df_sorted.iloc[0]
print(f"The best model in terms of proximity to mean coordinate and maximum slip of cluster is {best_model['Model']}")
print(f"MSE Coordinates: {best_model['MSE_Coordinates']:.6f}, MSE Max Slip: {best_model['MSE_Max_Slip']:.6f}")

# Display sorted DataFrame of all models in cluster 2
print(mse_df_sorted)
# Out:
# /Users/javieraalvarezvargas/opt/anaconda3/envs/ads/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Centroides de los clusters:
# Cluster 0: Lat = -33.965714285714284, Lon = -72.38162222741694
# Cluster 1: Lat = -32.86598639455782, Lon = -72.73067538798657
# Cluster 2: Lat = -33.161989795918366, Lon = -72.14806269074082
# Cluster
# 0    5
# 1    9
# 2    4
# dtype: int64
# El mejor modelo en términos de proximidad a la coordenada media y máximo slip del cluster es Model_17
# MSE Coordenadas: 0.001296, MSE Max Slip: 1.427737
#       Model  MSE_Coordinates  MSE_Max_Slip
# 7  Model_17         0.001296      1.427737
# 8  Model_18         0.001296      2.795447
# 5  Model_15         0.013624      2.068175
# 4  Model_14         0.020548      2.489097
# 6  Model_16         0.020548      9.384010
# ...
